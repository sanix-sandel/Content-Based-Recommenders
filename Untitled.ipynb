# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('metadata_clean.csv')

# %%
df.head()
# Out:
#                          title                              genres  runtime  \
# 0                    Toy Story   ['Animation', 'Comedy', 'Family']     81.0
# 1                      Jumanji  ['Adventure', 'Fantasy', 'Family']    104.0
# 2             Grumpier Old Men               ['Romance', 'Comedy']    101.0
# 3            Waiting to Exhale      ['Comedy', 'Drama', 'Romance']    127.0
# 4  Father of the Bride Part II                          ['Comedy']    106.0
#
#    vote_average  vote_count  year
# 0           7.7      5415.0  1995
# 1           6.9      2413.0  1995
# 2           6.5        92.0  1995
# 3           6.1        34.0  1995
# 4           5.7       173.0  1995

# %%
orig_df=pd.read_csv('movies_metadata.csv', low_memory=False)
#Add the useful features into the cleaned dataframe
df['overview'], df['id']=orig_df['overview'], orig_df['id']

df.head()
# Out:
#                          title                              genres  runtime  \
# 0                    Toy Story   ['Animation', 'Comedy', 'Family']     81.0
# 1                      Jumanji  ['Adventure', 'Fantasy', 'Family']    104.0
# 2             Grumpier Old Men               ['Romance', 'Comedy']    101.0
# 3            Waiting to Exhale      ['Comedy', 'Drama', 'Romance']    127.0
# 4  Father of the Bride Part II                          ['Comedy']    106.0
#
#    vote_average  vote_count  year  \
# 0           7.7      5415.0  1995
# 1           6.9      2413.0  1995
# 2           6.5        92.0  1995
# 3           6.1        34.0  1995
# 4           5.7       173.0  1995
#
#                                             overview     id
# 0  Led by Woody, Andy's toys live happily in his ...    862
# 1  When siblings Judy and Peter discover an encha...   8844
# 2  A family wedding reignites the ancient feud be...  15602
# 3  Cheated on, mistreated and stepped on, the wom...  31357
# 4  Just when George Banks has recovered from his ...  11862

# %% [markdown]
# ### Creating the TF-IDF matrix

# %%
#Import TfidfVectorizer from the scikit-learn library
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#Define a TF-IDF Vectorizer Object. Remove all english stopwords
tfidf=TfidfVectorizer(stop_words='english')

# %%
#Replace NaN with an empty string
df['overview']=df['overview'].fillna('')

# %%
#Construct the required TF-IDF matrix by applying the fit_transform method on the overrview feature
tfidf_matrix=tfidf.fit_transform(df['overview'])

# %%
#output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (45466, 75827)

# %% [markdown]
# ### Computing the cosine similarity score

# %%
#Import linear_kernel to compute the dot product
from sklearn.metrics.pairwise import linear_kernel

# %%
#Compute the cosine similarity matrix
cosine_sim=linear_kernel(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# ### Building the recommender function

# %%
#Construct a reverse mapping of indice and movie titles, and drop duplicate titles, if any
indices=pd.Series(df.index, index=df['title']).drop_duplicates()

# %%
#Function that takes in movie title as input and gives recommendations 
def content_recommender(title, cosine_sim=cosine_sim, df=df, indices=indices):
    #Obtain the index of the movie that matches the title
    idx=indices[title]
    
    #Get the pairwise similarity scores of all movies with movie
    #And convert it into a list of tuples as described above
    sim_scores=list(enumerate(cosine_sim[idx]))
    
    #Sort the movies based on the cosine similarity scores
    sim_scores=sorted(sim_scores, key=lambda x:x[1], reverse=True)
    
    #Get the scores of the 10 most similar movies. Ignore the first movie.
    sim_scores=sim_scores[1:11]
    
    #Get the movie indices
    movie_indices=[i[0] for i in sim_scores]
    
    #Return the top 10 most similar movies
    return df['title'].iloc[movie_indices]

# %%
content_recommender('Dracula: Dead and Loving It')
# Out:
# 21540             Dracula 3D
# 181                    Nadja
# 3905            Dracula 2000
# 8689       Dracula A.D. 1972
# 1291                 Dracula
# 5512       Horror of Dracula
# 41124    Manson's Lost Girls
# 21650     A Jitney Elopement
# 31724             Pale Blood
# 451                    Fresh
# Name: title, dtype: object

# %%
df.head(20)
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# 5                             Heat
# 6                          Sabrina
# 7                     Tom and Huck
# 8                     Sudden Death
# 9                        GoldenEye
# 10          The American President
# 11     Dracula: Dead and Loving It
# 12                           Balto
# 13                           Nixon
# 14                Cutthroat Island
# 15                          Casino
# 16           Sense and Sensibility
# 17                      Four Rooms
# 18  Ace Ventura: When Nature Calls
# 19                     Money Train
#
#                                         genres  runtime  vote_average  \
# 0            ['Animation', 'Comedy', 'Family']     81.0           7.7
# 1           ['Adventure', 'Fantasy', 'Family']    104.0           6.9
# 2                        ['Romance', 'Comedy']    101.0           6.5
# 3               ['Comedy', 'Drama', 'Romance']    127.0           6.1
# 4                                   ['Comedy']    106.0           5.7
# 5     ['Action', 'Crime', 'Drama', 'Thriller']    170.0           7.7
# 6                        ['Comedy', 'Romance']    127.0           6.2
# 7   ['Action', 'Adventure', 'Drama', 'Family']     97.0           5.4
# 8          ['Action', 'Adventure', 'Thriller']    106.0           5.5
# 9          ['Adventure', 'Action', 'Thriller']    130.0           6.6
# 10              ['Comedy', 'Drama', 'Romance']    106.0           6.5
# 11                        ['Comedy', 'Horror']     88.0           5.7
# 12        ['Family', 'Animation', 'Adventure']     78.0           7.1
# 13                        ['History', 'Drama']    192.0           7.1
# 14                     ['Action', 'Adventure']    119.0           5.7
# 15                          ['Drama', 'Crime']    178.0           7.8
# 16                        ['Drama', 'Romance']    136.0           7.2
# 17                         ['Crime', 'Comedy']     98.0           6.5
# 18            ['Crime', 'Comedy', 'Adventure']     90.0           6.1
# 19               ['Action', 'Comedy', 'Crime']    103.0           5.4
#
#     vote_count  year                                           overview     id
# 0       5415.0  1995  Led by Woody, Andy's toys live happily in his ...    862
# 1       2413.0  1995  When siblings Judy and Peter discover an encha...   8844
# 2         92.0  1995  A family wedding reignites the ancient feud be...  15602
# 3         34.0  1995  Cheated on, mistreated and stepped on, the wom...  31357
# 4        173.0  1995  Just when George Banks has recovered from his ...  11862
# 5       1886.0  1995  Obsessive master thief, Neil McCauley leads a ...    949
# 6        141.0  1995  An ugly duckling having undergone a remarkable...  11860
# 7         45.0  1995  A mischievous young boy, Tom Sawyer, witnesses...  45325
# 8        174.0  1995  International action superstar Jean Claude Van...   9091
# 9       1194.0  1995  James Bond must unmask the mysterious head of ...    710
# 10       199.0  1995  Widowed U.S. president Andrew Shepherd, one of...   9087
# 11       210.0  1995  When a lawyer shows up at the vampire's doorst...  12110
# 12       423.0  1995  An outcast half-wolf risks his life to prevent...  21032
# 13        72.0  1995  An all-star cast powers this epic look at Amer...  10858
# 14       137.0  1995  Morgan Adams and her slave, William Shaw, are ...   1408
# 15      1343.0  1995  The life of the gambling paradise – Las Vegas ...    524
# 16       364.0  1995  Rich Mr. Dashwood dies, leaving his second wif...   4584
# 17       539.0  1995  It's Ted the Bellhop's first night on the job....      5
# 18      1128.0  1995  Summoned from an ashram in Tibet, Ace finds hi...   9273
# 19       224.0  1995  A vengeful New York transit cop decides to ste...  11517
